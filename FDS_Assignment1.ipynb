# %% [markdown]
# # Fundamentals of Data Science
# Winter Semester 2021
#
# ## Prof. Fabio Galasso, Guido D'Amely, Alessandro Flaborea, Luca Franco, Muhammad Rameez Ur Rahman and Alessio Sampieri
# <galasso@di.uniroma1.it>, <damely@di.uniroma1.it>, <flaborea.1841969@studenti.uniroma1.it>, <franco.luca.17@gmail.com>, <rahman@di.uniroma1.it>, <alessiosampieri27@gmail.com>
#
# ## Exercise 1: Image Filtering and Object Identification

# %% [markdown]
# In this exercise you will first familiarise yourself with the basic image filtering routines of Python and NumPy (**Question 1**), then develop a simple image querying system which accepts a query image as input and then finds a set of similar images in the database (**Question 2, 3 and 4**).
#
# This notebook consists of essential functions to solve assignment and questions to be implemented; your task is to fill the missing code "YOUR CODE HERE" part corresponding to each subproblem and produce brief reports on the results whenever necessary.
#
# The filtering part contains two images: *graph.png* and *brick_aliasing.jpg*, which we will use for testing purposes.
#
# In the identification part, you will compare images with several distance functions and evaluate their performance in combination with different image representations. The identification part contains query and model images
# for the evaluation, which correspond to the same set of objects photographed from different viewpoints. The files model.txt and query.txt contain lists of image files arranged so that i-th model image depicts the same object as i-th query image. The placeholder scripts will also be used to test your solution.
#
# As part of the exercise, provide an answer to questions in this notebook, in a report-like manner. After you have implemented all the missing code in both exercise parts, you should be able to execute those without errors. Use those to support your answers in the report answers.
#
# The completed exercise should be handed in as a single notebook file. Use Markdown to provide equations. Use the code sections to provide your scripts and the corresponding plots.
# Submit it by sending an email to galasso@di.uniroma1.it, damely@di.uniroma1.it, rahman@di.uniroma1.it and alessiosampieri27@gmail.com by Wednesday October 20th, 23:59.

# %% [markdown]
# ## Question 1: Image Filtering **(9 Points)**

# %% [markdown]
# Import some useful libraries

# %%
## import packages

import numpy as np
from PIL import Image
from scipy.signal import convolve2d as conv2, convolve
import matplotlib.pyplot as plt
import cv2
import math

plt.rcParams["figure.figsize"] = (20,8)

# %%
# !pip3 install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /Users/valentinosacco/opt/anaconda3/lib/python3.8/site-packages (4.5.3.56)
# Requirement already satisfied: numpy>=1.17.3 in /Users/valentinosacco/opt/anaconda3/lib/python3.8/site-packages (from opencv-python) (1.20.1)

# %%
def rgb2gray(rgb):
  '''
  RGB -> gray_scale
  '''
  r, g, b = rgb[:,:,0], rgb[:,:,1], rgb[:,:,2]
  gray = 0.2989 * r + 0.5870 * g + 0.1140 * b
  return gray

# %% [markdown]
# ### Exercise 1 - Code **(7 Points)**

# %% [markdown]
# #### Exercise 1.a **(3 Points)**

# %% [markdown]
# ##### 1-D Gaussian Filter
# Implement a method which computes the values of a 1-D Gaussian *Gx* for a given standard deviation $\sigma$ :
# \begin{equation}
# G=\frac{1}{\sqrt{2\pi}\sigma}\exp(-\frac{x^2}{2\sigma^2})
# \end{equation}
#
# The method should also return a vector *x* of values on which the Gaussian filter is defined: integer values on the interval $\left[-3\sigma,3\sigma\right]$.
#
# This should be the output with $\sigma=3$.
#
#
# ![](https://drive.google.com/uc?export=view&id=1Q3WIdozsroKzinnlyZhgZHFMdYj7KQrw)

# %%
def gauss(sigma):
    
    # Gaussian distribution definition
    gaussian = lambda y : (1 / (math.sqrt(2*math.pi) * sigma) ) * math.exp(- (y**2) / (2*(sigma**2)))  
    # Filtering X on filter definition interval 
    x = np.arange(-3*sigma, (3*sigma)+0.01)
    # Applying gaussian to filtered points
    Gx = list(map(gaussian, x))
    
    return Gx , x

# %% [markdown]
# ################# Do not write below this line just run #################

# %%
## function gauss
sigma = 3
Gx,x = gauss(sigma)
plt.figure(1)
plt.plot(x, Gx, '.-')
plt.show()

# %% [markdown]
# ##### 1-D Box Filter
#
# Implement a method which computes the values of a 1-D Box *Bx* for a given standard deviation $\sigma$ :
# \begin{equation}
# B= [\frac{1}{n},\frac{1}{n},\dots,\frac{1}{n}]\in \mathbb{R}^n
# \end{equation}
#
# The method should also return a vector *x* of values on which the **Box** filter is defined: integer values on the interval $\left[-3\sigma,3\sigma\right]$.
#
# An example of Box Filter:
#
# ![](https://drive.google.com/uc?export=view&id=1UBpSRYNkZnK2UGmGsMSnrmzwrPyMt6Fz)

# %%
def box(filter_size=3,show_verbose=False): 
    # initializing box function
    Box = lambda x: 1/filter_size
    # filtering xs among box dimension
    x = np.arange(-(filter_size-1)/2,(filter_size-1)/2+1,1)
    # box filtered x
    Bx = list(map(Box, x))
    
    return Bx,x

# %% [markdown]
# ################# Do not write below this line just run #################

# %%
## function box
size = 3
Bx,x = box(size)
plt.figure(1)
plt.plot(x, Bx, '.-')
plt.show()

# %% [markdown]
# ##### 2-D custom filter
# Recreate the given 3x3 filter:
#
# \begin{bmatrix}
# -0.015 & -0.035 & -0.015\\
# -0.035 & 0.8 &  -0.035 \\
# -0.015 & -0.035 & -0.015
# \end{bmatrix}
#
#  The absolute value of the elements in the kernel sum to 1, in the middle position we find 80% of the weights and in the corners 30% of the remaining percentage with negative sign.

# %%
def custom():
    
    Gx = np.array([[-0.015, -0.035, -0.015],[-0.035, 0.8, -0.035], [-0.015, -0.035,-0.015]] )
    
   # Gx = [[-0.015, -0.035,-0.015],[-0.035, 0.8, -0.035],[-0.015, -0.035,-0.015]]

    return Gx

# %% [markdown]
# ################# Do not write below this line just run #################

# %%
custom_filter = custom()
print(custom_filter)
# Out:
# [[-0.015 -0.035 -0.015]
#  [-0.035  0.8   -0.035]
#  [-0.015 -0.035 -0.015]]

# %% [markdown]
# ##### Gauss derivative 1-D
# Implement a function gaussdx for creating a Gaussian derivative filter in 1D:
# $$
# \frac{d}{dx}G =-\frac{1}{\sqrt{2\pi}\sigma^3}x\exp({-\frac{x^2}{2\sigma^2}})
# $$
# As in 1.a-1.b, the function should also return a vector x of values on which the Gaussian derivative filter is
# defined: integer values on the interval $[3\sigma; 3\sigma]$.
#
# An example of Gauss derivative 1-D:
#
# ![](https://drive.google.com/uc?export=view&id=1QZmVMxJiOARKe5MoqzZ7SSSjFikoY2ty)

# %%
def gaussdx(sigma):  #Same principle as the gauss(sigma) function
    
    dxgaussian = lambda y :-y*math.exp(-(y**2)/(2*(sigma**2)))/((sigma**3)*math.sqrt(2*math.pi))
    x = np.arange(-int(3*sigma), int(3*sigma)+1,1)
    Dx = list(map(dxgaussian, x))
    
    return Dx, x

# %% [markdown]
# ################# Do not write below this line just run #################

# %%
## function gaussdx
sigma = 3
DGx,x = gaussdx(sigma)
plt.figure(1)
plt.plot(x, DGx, '.-')
plt.show()

# %% [markdown]
# #### Exercise 1.b **(3 Points)**
#
# Here you have to convolve the filters you have just defined with the given image _'graf.png'_. Remember that "Box" and "Gaussian" filters are separable.

# %% [markdown]
# ##### 2-D Gaussian filter
# The function should take an image as an input
# and return the result of convolution of this image with 2D Gaussian kernel. You can take advantage of the Python’s convolve2D function if you don’t want to
# implement convolution yourself.
#
# See figure below for illustration
# of Gaussian filtering.
# ![](https://drive.google.com/uc?export=view&id=1GtsTZXlnj811pJi1VnamdtDCvhqHiu8j)

# %%
def gaussfiltering(img, sigma):
    Gx,x = gauss(sigma)
    # Gaussian filter
    Gx = np.array(Gx)
    gauss_filter = np.outer(Gx,Gx.transpose())
    # Smoothing the image by convolving it with kernel and keeping same size, centered
    smooth_img = conv2(img,gauss_filter, mode='same', boundary='fill')
    return np.array(smooth_img)

# %% [markdown]
# ################# Do not write below this line just run #################

# %%
img = rgb2gray(np.array(Image.open('graf.png')))
smooth_img = gaussfiltering(img, 5)
print(smooth_img.shape)
plt.figure(2)
ax1 = plt.subplot(1,2,1)
ax1.set_xlabel('Input Image')
ax2 = plt.subplot(1,2,2)
ax2.set_xlabel('Gaussian Filtered Image')
plt.sca(ax1)
plt.imshow(img, cmap='gray', vmin=0, vmax=255)
plt.sca(ax2)
plt.imshow(smooth_img, cmap='gray', vmin=0, vmax=255)
plt.show()
# Out:
# (640, 800)

# %% [markdown]
# ##### 2-D Box filter
# The function should take an image as an input
# and return the result of convolution of this image with 2D Box kernel.
#
# See figure below for illustration of Box filtering.
#
# ![Original Image](https://drive.google.com/uc?export=view&id=1IMrJUuTouVHmaiiyWB6H1QbKLzYTg9qC)

# %%
def boxfiltering(img, filter_size):

  Bx,x = box(filter_size)
  Bx = np.array(Bx)
  box_filter = np.outer(Bx,Bx.transpose())   #Create the Convolution Matrix of the Box Filter
  smooth_img = conv2(img,box_filter,mode = 'same', boundary = 'fill')

  return np.array(smooth_img)

# %% [markdown]
# ################# Do not write below this line just run #################

# %%
img = rgb2gray(np.array(Image.open('graf.png')))
smooth_img = boxfiltering(img, 10)
plt.figure(2)
ax1 = plt.subplot(1,2,1)
ax1.set_xlabel('Input Image')
ax2 = plt.subplot(1,2,2)
ax2.set_xlabel('Box Filtered Image')
plt.sca(ax1)
plt.imshow(img, cmap='gray', vmin=0, vmax=255)
plt.sca(ax2)
plt.imshow(smooth_img, cmap='gray', vmin=0, vmax=255)
plt.show()

# %% [markdown]
# ##### Custom Filter
#
# The function should take an image and return the result of the convolution of this image with the custom filter we have defined in exercise 1.a.
#
# See figure below for an illustration of this custom filter.
#
# ![](https://drive.google.com/uc?export=view&id=1N1wEkhqOuAX3TusQNNxN9KPOXb9nRsFn)

# %%
def customfiltering(img):

  custom_filter = custom()
  smooth_img = conv2(img, custom_filter,mode='same', boundary = 'fill')
  return np.array(smooth_img)

# %% [markdown]
# ################# Do not write below this line just run #################

# %%
img = rgb2gray(np.array(Image.open('graf.png')))
smooth_img = customfiltering(img)
#print(smooth_img.shape)
plt.figure(2)
ax1 = plt.subplot(1,2,1)
ax1.set_xlabel('Input Image')
ax2 = plt.subplot(1,2,2)
ax2.set_xlabel('Custom Filtered Image')
plt.sca(ax1)
plt.imshow(img, cmap='gray', vmin=0, vmax=255)
plt.sca(ax2)
plt.imshow(smooth_img, cmap='gray', vmin=0, vmax=255)
plt.show()

# %% [markdown]
# #### Exercise 1.c **(1 Points)**
#
# Implement a Gaussian Pyramid: Write a function for downscaling (you can use the function [resize from cv2](https://docs.opencv.org/master/dd/d52/tutorial_js_geometric_transformations.html) library) and use the Gaussian filter to blur it. The Pyramid must consist of three steps:
#
# * Apply Gaussian filter on original Image
# * Resize (Downscale) the smoothed image (obtained from previous step) and apply Gaussian filter again.
# * Resize (Downscale) the smoothed image (obtained from previous step) and apply Gaussian filter again.
#
# See figure below for an illlustration of Gaussian Pyramid.
# ![](https://drive.google.com/uc?export=view&id=1JKeyNozWgoBWHqrUwj4SEF6SJEnO9uMt)

# %%
def downscale(img, factor):
    
    
    '''
  This function should return the given image
  resized by the factor.
  Input:
    img: the image to resize
    factor: the factor you want use to downscale
  Output:
    resized: the resized image
  '''
    width = int(img.shape[1] * factor)
    height = int(img.shape[0] * factor)
    resized_img = cv2.resize(img,(width,height))

    return resized_img

# %%
def GaussianPyramid(img, steps=3, factor=0.5, sigma=4):
    
    for i in range(steps):
      smooth_img = gaussfiltering(img, sigma)
      plt.figure(2)
      ax1 = plt.subplot(1,2**(i+1),1)
      ax1.set_xlabel('Input Image')
      ax2 = plt.subplot(1,2**(i+1),2)
      ax2.set_xlabel('Gaussian Filtered Image')
      plt.sca(ax1)
      plt.imshow(img, cmap='gray', vmin=0, vmax=255)
      plt.sca(ax2)
      plt.imshow(smooth_img, cmap='gray', vmin=0, vmax=255)
      plt.show()
      img = downscale(smooth_img, factor)
    return

# %% [markdown]
# ################# Do not write below this line just run #################

# %%
img = rgb2gray(np.array(Image.open('graf.png')))
GaussianPyramid(img)

# %% [markdown]
# ### Exercise 1 - Report **(2 Points)**
#
# Use the images from the previous exercises to write a report on what you learned about filters and convolutions **(in the text block below)**.
# In report, you should also compare your results: use the three filters you just created and apply on 'brick_aliasing.jpg' file and identify which filter is applied on Image A, Image B and Image C illustrated in Figure below. Use 7 as filter_size both for Gaussian and Box filter.
#
# ![](https://drive.google.com/uc?export=view&id=1eDOTU7FIRht9WMiAeW3ZlsFnpAlW_ZGm)

# %% [markdown]
# **Write your Report here**
#
#
# - Image A filter -> Gaussian Filter, sigma=7
# - Image B filter -> Box Filter, n=7
# - Image C filter -> Custom Filter
#
# We can use Gaussian Filter to blur (removing details) and reduce noise , according with the size of sigma (larger values of sigma produce a greater blurring). So, if we convolve a 2-D Gaussian filter with our image, the result will be a new image smoothed.
# This filter is non-uniform because the central pixels have a higher weight than the further ones, according to the bell-shape of the gaussian distribution.
# Box-filter returns a smoothed image too. The  main difference is that here all the pixels  are weighed equally (the average value of its neighbors). Thanks to the examples it can be seen that a box-filter produces a relatively minor blur (taking the same value for n and sigma) and also a slightly brighter image.
# In the custom filter the absolute value of the elements in the kernel sum to 1,in the center there is most of the weight and the rest has  negative sign: as a result of that the image is not blurred but it got darker.

# %%
img = rgb2gray(np.array(Image.open('brick_aliasing.jpg')))
smooth_img = gaussfiltering(img, 7)
print(smooth_img.shape)
plt.figure(2)
ax1 = plt.subplot(1,2,1)
ax1.set_xlabel('Input Image')
ax2 = plt.subplot(1,2,2)
ax2.set_xlabel('Gaussian Filtered Image')
plt.sca(ax1)
plt.imshow(img, cmap='gray', vmin=0, vmax=255)
plt.sca(ax2)
plt.imshow(smooth_img, cmap='gray', vmin=0, vmax=255)
plt.show()
# Out:
# (333, 413)

# %%
img = rgb2gray(np.array(Image.open('brick_aliasing.jpg')))
smooth_img = boxfiltering(img, 7)
plt.figure(2)
ax1 = plt.subplot(1,2,1)
ax1.set_xlabel('Input Image')
ax2 = plt.subplot(1,2,2)
ax2.set_xlabel('Box Filtered Image')
plt.sca(ax1)
plt.imshow(img, cmap='gray', vmin=0, vmax=255)
plt.sca(ax2)
plt.imshow(smooth_img, cmap='gray', vmin=0, vmax=255)
plt.show()

# %% [markdown]
# ## Question 2: Identification **(10 Points)**

# %% [markdown]
# Import some useful libraries

# %%
## import packages
import numpy as np
from PIL import Image
from numpy import histogram as hist
import matplotlib.pyplot as plt
import math

# %%
def rgb2gray(rgb):
  r, g, b = rgb[:, :, 0], rgb[:, :, 1], rgb[:, :, 2]
  gray = 0.2989 * r + 0.5870 * g + 0.1140 * b
  return gray

# %% [markdown]
# ### Exercise 2 - Code

# %% [markdown]
# #### Exercise 2.a **(3 Points)**
# For this question,  implement the
# function **normalized hist**, which takes gray-value image as input and returns normalized histogram of
# pixel intensities. When quantizing the image to compute the histogram, consider that pixel intensities
# range in $[0, 255]$.
# Compare your implementation with built-in Python function numpy.histogram. Your histograms and
# histograms computed with Python should be approximately the same. (3 points)

# %%
def normalized_hist(img_gray, num_bins = 40, show_verbose = False):
    hists=np.zeros(num_bins,dtype=int)
    bins=np.zeros(num_bins+1)
    bins_width=256/num_bins
    
     
    
    for el in img_gray.flat:
        binNumber=math.floor(el/bins_width)
        hists[binNumber]+=1
    hists=hists/sum(hists)
    for j in range(num_bins+1):
        bins[j]=bins_width*j
        
    
     # '''
  #Compute histogram of image intensities, histogram should be normalized so that sum of all values equals 1
  #assume that image intensity is between 0 and 255

  #img_gray - input image in grayscale format
  #um_bins - number of bins in the histogram

  
  
    return hists, bins

# %% [markdown]
# ################# Do not write below this line just run #################

# %%
img_color = np.array(Image.open('model/obj100__0.png'))
img_gray = rgb2gray(img_color.astype('double'))

plt.figure(1)
plt.subplot(1,3,1)
plt.imshow(img_gray,cmap='gray', vmin=0, vmax=255)

plt.subplot(1,3,2)
num_bins_gray = 40
hist_gray1, bin_gray1 = hist(img_gray.reshape(img_gray.size), num_bins_gray,(0,255))
plt.bar((bin_gray1[0:-1] + bin_gray1[1:])/2, hist_gray1, width=3)

plt.subplot(1,3,3)
hist_gray2, bin_gray2 = normalized_hist(img_gray, num_bins_gray)
plt.bar((bin_gray2[0:-1] + bin_gray2[1:])/2, hist_gray2, width=3)
plt.show()

# %% [markdown]
# #### Exercise 2.b **(6 Points)**
# Implement the histogram types. Your implementation should
# complete the scripts provided in the functions rgb_hist, rg_hist and dxdy_hist.
# As above, when quantizing the images to compute the histogram, consider that “RGB” and “RG” range in
# $[0, 255]$. For the case of dxdy hist, the actual image value ranges depend on the chosen Gaussian filtering
# variance, used when computing the derivative. For this exercise, set the standard deviation $σ = 3.0$ and
# cap the pixel values to be in the range $[−6, 6]$, i.e. set all values below (above) the value of -6 (+6) to -6
# (+6). (3 points)

# %% [markdown]
# ##### RGB

# %%
def rgb_hist(img_color_double, num_bins = 5, show_verbose = False):
    '''
    Compute the *joint* histogram for each color channel in the image
    The histogram should be normalized so that sum of all values equals 1
    Assume that values in each channel vary between 0 and 255

    img_color - input color image
    num_bins - number of bins used to discretize each channel, total number of bins in the histogram should be num_bins^3

    E.g. hists[0,9,5] contains the number of image_color pixels such that:
      - their R values fall in bin 0
      - their G values fall in bin 9
      - their B values fall in bin 5
    '''

    # initializing hists
    hists = np.zeros((num_bins, num_bins, num_bins), dtype=int)
    
    # get width
    bins_width = 256 / num_bins
    
    # for every 3D pixel in img_color
    for R,G,B in img_color_double.reshape(-1, 3):
        # normalization factor
        # normFactor = R+G+B
        redBin,greenBin, blueBin = math.floor(R/bins_width), math.floor(G/bins_width),math.floor(B/bins_width)
        hists[redBin, greenBin, blueBin]+=1
        
    summ = np.sum(a=hists, axis=None)
    hists = hists/summ
    
    return hists.flatten()

# %% [markdown]
# ################# Do not write below this line just run #################

# %%
# Compose and test RGB histograms (rgb_hist)
plt.figure(2)
plt.subplot(1,2,1)
plt.imshow(img_color)

num_bins_color = 5

plt.subplot(1,2,2)
hist_rgb1 = rgb_hist(img_color.astype('double'), num_bins_color)
plt.bar(np.array(range(1, hist_rgb1.size+1)),hist_rgb1)
# Out:
# <BarContainer object of 125 artists>

# %% [markdown]
# ##### RG

# %%
def rg_hist(img_color_double, num_bins = 5, show_verbose = False):
    '''
    Compute the *joint* histogram for the R and G color channels in the image
    The histogram should be normalized so that sum of all values equals 1
    Assume that values in each channel vary between 0 and 255

    img_color - input color image
    num_bins - number of bins used to discretize each channel, total number of bins in the histogram should be num_bins^2

    E.g. hists[0,9] contains the number of image_color pixels such that:
      - their R values fall in bin 0
      - their G values fall in bin 9
    '''

    hist = np.zeros((num_bins, num_bins), dtype=int)
    bins_width = 256 / num_bins
    
    for i in range(img_color_double.shape[0]) :
        for j in range(img_color_double.shape[1]) :
            
            r = img_color_double[i, j][0]
            g = img_color_double[i, j][1]
            
            hist[math.floor(r/bins_width),math.floor(g/bins_width)] +=1
    hist = hist / np.sum(hist, axis=None)
    return hist.flatten()

# %% [markdown]
# ################# Do not write below this line just run #################

# %%
#Compose and test RG histograms (histogram_module.rg_hist)
plt.figure(3)
plt.subplot(1,2,1)
plt.imshow(img_color)

num_bins_color = 5
plt.subplot(1,2,2)
hist_rg = rg_hist(img_color.astype('double'), num_bins_color)
plt.bar(np.array(range(1,hist_rg.size+1)),hist_rg)
plt.show()

# %% [markdown]
# ##### DXDY

# %%
def gaussderiv(img, sigma):
    
    Dx, x =  np.array(gaussdx(sigma))
    Dx = Dx.reshape(-1,1)
    
    smooth_imgDx = conv2(img,Dx, mode='same', boundary='wrap')
    imgDx = np.array(smooth_imgDx)
    smooth_imgDy = conv2(img,Dx.T, mode='same', boundary='wrap')
    imgDy = np.array(smooth_imgDy)
    
    return imgDx, imgDy

# %%
img_color = np.array(Image.open('model/obj100__0.png'))
img_gray = rgb2gray(img_color.astype('double'))
smooth_img1, smooth_img2 = gaussderiv(img_gray, 3)
plt.figure(2)
ax1 = plt.subplot(1,3,1)
ax1.set_xlabel('Input Image')
ax2 = plt.subplot(1,3,2)
ax2.set_xlabel('Gaussian Filtered Image')
ax3 = plt.subplot(1,3,3)
plt.sca(ax1)
plt.imshow(img_color, cmap='gray', vmin=0, vmax=255)
plt.sca(ax2)
plt.imshow(smooth_img1)
plt.sca(ax3)
plt.imshow(smooth_img2)
plt.show()

# %%
def dxdy_hist(img_gray, num_bins = 5, show_verbose = False):
    '''
    Compute the *joint* histogram of Gaussian partial derivatives of the image in x and y direction
    Set sigma to 3.0 and cap the range of derivative values is in the range [-6, 6]
    The histogram should be normalized so that sum of all values equals 1

    img_gray - input gray value image
    num_bins - number of bins used to discretize each dimension, total number of bins in the histogram should be num_bins^2

    Note: you can use the function gaussderiv from the Filtering exercise
    '''

    dx,dy = gaussderiv(img_gray, 3)
    dx,dy = np.clip(dx, -6, 6),np.clip(dy, -6, 6)
    hist = np.zeros((num_bins, num_bins), dtype=int)
    bins_width = 13 / num_bins
    print("width", bins_width)
    
    for i in range(img_gray.shape[0]) :
        for j in range(img_gray.shape[1]):
            binX = math.floor(dx[i][j]  / bins_width)
            binY = math.floor(dy[i][j]  / bins_width)
            hist[binX, binY] += 1
         
    hist = hist / np.sum(hist, axis=None)
    return hist.flatten()

# %% [markdown]
# ################# Do not write below this line just run #################

# %%
#Compose and test dxdy histograms (histogram_module.dxdy_hist)

plt.figure(5)
plt.subplot(1,2,1)
plt.imshow(img_color)

num_bins_dxdy = 10
plt.subplot(1,2,2)
hist_dxdy = dxdy_hist(img_gray, num_bins_dxdy)
plt.bar(np.array(range(1,hist_dxdy.size+1)),hist_dxdy)
plt.show()
# Out:
# width 1.3

# %% [markdown]
# #### Exercise 2.c **(1 Point)**
# Implement the histogram distance functions.
#
# In more details, implement the function *dist_intersect*:
# \begin{equation}
# \bigcap(Q,V)=1-\frac{1}{2}\left(
# \frac{\sum_i \min(q_i,v_i)}{\sum_i q_i} +
# \frac{\sum_i \min(q_i,v_i)}{\sum_i v_i}
# \right)
# \end{equation}
#
# the *dist_l2* function:
# \begin{equation}
# d(Q,V)=\sqrt{\sum_i (q_i-v_i)^2}
# \end{equation}
#
# and the *dist_chi2*:
# \begin{equation}
# \chi^2(Q,V)=\sum_i \frac{(q_i-v_i)^2}{q_i + v_i}
# \end{equation}

# %%
def dist_intersect(x,y):
    '''
    Compute the intersection distance between histograms x and y
    Return 1 - hist_intersection, so smaller values correspond to more similar histograms
    Check that the distance range in [0,1]
    '''

    nom = (sum([min(x[i], y[i]) for i in range(len(x))]))
    den_x,den_y  = sum(x),sum(y)
    
    assert(den_x > 0 and den_y > 0), "Invalid input : Histograms should not sum up to 0!"
    
    sm =  nom / den_x
    sm1 = nom / den_y 
    
    hist_intersection = (sm+sm1)*0.5
    dist = 1 - hist_intersection
    
    assert(dist <= 1 and dist >= 0 ), "Invalid dist : Dist must be in range [0,1]"  
    return dist
    


def dist_l2(x,y):
    '''
    Compute the L2 distance between x and y histograms
    Check that the distance range in [0,sqrt(2)]
    '''

    # My impl
    dist = math.sqrt(sum([( x[i] - y[i])**2 for i in range(len(x))]))
    # "Check that the distance range in [0,sqrt(2)]"
    assert(dist <= math.sqrt(2) and dist >= 0 ), "Invalid dist : Dist must be in range [0,sqrt(2)]"
    return dist


def dist_chi2(x,y):
    chi2_dist=0
    for i in range(len(x)):
        chi2_dist+= pow((x[i]-y[i]),2)/(x[i]+y[i])
        
    
    '''
    Compute chi2 distance between x and y
    Check that the distance range in [0,Inf]
    Add a minimum score to each cell of the histograms (e.g. 1) to avoid division by 0
    '''
    
    assert(chi2_dist >= 0), "Invalid distance : distance can't be negative"
  
    return chi2_dist

# %% [markdown]
# ## Question 3: Object Identification **(11 Points)**

# %% [markdown]
# ### Exercise 3 - Code **(7 Points)**

# %% [markdown]
# #### Exercise 3.a **(4 Points)**
# Having implemented different distance functions and image histograms, you can now test how suitable
# they are for retrieving images in query-by-example scenario. Implement a function find_best_match which takes a list of model images and a list of query images and for each query im-
# age returns the index of closest model image. The function should take string parameters, which identify
# distance function, histogram function and number of histogram bins. See comments in the beginning of
# find_best_match function for more details. Additionally to the indices of the best matching images your implemen-
# tation should also return a matrix which contains distances between all pairs of model and query images.
# (3 points)

# %%
def is_grayvalue_hist(hist_name):
  '''
  Handle function to discriminate when your input 
  function is in gray_scale or colors.
  '''
  if hist_name == 'grayvalue' or hist_name == 'dxdy':
    return True
  elif hist_name == 'rgb' or hist_name == 'rg':
    return False
  else:
    assert False, 'unknown histogram type'


def get_hist_by_name(img, num_bins_gray, hist_name):
  '''
  Handle function to get the correct historgam function 
  by his name.
  '''
  if hist_name == 'grayvalue':
    return normalized_hist(img, num_bins_gray)
  elif hist_name == 'rgb':
    return rgb_hist(img, num_bins_gray)
  elif hist_name == 'rg':
    return rg_hist(img, num_bins_gray)
  elif hist_name == 'dxdy':
    return dxdy_hist(img, num_bins_gray)
  else:
    assert False, 'unknown hist type: %s'%hist_name


def get_dist_by_name(x, y, dist_name):
  '''
  Handle function to get the correct distance function 
  by his name.
  '''
  if dist_name == 'chi2':
    return dist_chi2(x,y)
  elif dist_name == 'intersect':
    return dist_intersect(x,y)
  elif dist_name == 'l2':
    return dist_l2(x,y)
  elif dist_name == 'all':
    pass
  else:
    assert False, 'unknown distance: %s'%dist_name

def read_files():
  '''
  Handle function to read query and model files
  '''
  with open('model.txt') as fp:
    model_images = fp.readlines()
  model_images = [x.strip() for x in model_images]

  with open('query.txt') as fp:
    query_images = fp.readlines()
  query_images = [x.strip() for x in query_images]

  return query_images, model_images

# %%
# note: use functions 'get_dist_by_name', 'get_hist_by_name' and 'is_grayvalue_hist' to obtain 
#       handles to distance and histogram functions, and to find out whether histogram function 
#       expects grayvalue or color image

def compute_histograms(image_list, hist_type, hist_isgray, num_bins):
    '''
    this function returns a list containing the histograms for
    the list of images given as input.
    '''
    out = []
    
    for img in image_list :
        img = np.array(Image.open(img))
        out.append(
            get_hist_by_name(
                rgb2gray(img) if hist_isgray else img,
                num_bins,
                hist_type
            )
        )
    return out



def find_best_match(model_images, query_images, dist_type, hist_type, num_bins):
    
    '''
    Function to find the best match for each image in the 
    query folder.
    Input:
    model_images: list of strings with the path of model images.
    query_images: list of strings with the path of query images.
    dist_type:    a string to represent the name of the distance you want to 
                  use. Should be one among "l2", "intersect", "chi2".
    hist_type:    a string to represent the name of the histogram you want to 
                  use. Should be one among "grayvalue", "rgb", "rg", "dxdy".

    Output:
    best_match:   list containing in each position the index of the retrieved
                  best matching image.
    D:            Matrix with |model_images| rows and |query_images| columns
                  containing the scores of each matching.
    '''
    

    
    
    assert(dist_type in ["l2", "intersect", "chi2"]), "unknown dist!"
    rows = len(model_images)
    cols = len(query_images)
    
    best_match = list()
    D = np.zeros((rows, cols))
    
    print("[ Finding best match among : \n\t(ROWS) - {} model Images \n\t(COLS) - {} query Images ]".format(rows, cols))
    print("[ Started computing model histograms ]")
    
    # Computing model images hists
    model_histograms = compute_histograms(model_images, hist_type, is_grayvalue_hist(hist_type), num_bins)
    print("[ Finished computing model histograms ]")
    
    print("[ Started computing query histograms ]")
    # Computing input images hists
    query_histograms = compute_histograms(query_images, hist_type, is_grayvalue_hist(hist_type), num_bins)
    
    current_col = 0
    
    for q_hist in query_histograms :
        print("[ Computing distances for query #{} ]".format(current_col))
        
        # assigning temporary values
        current_row = 0
        top_match = 1
        top_match_row = 0
        
        # Find distances with model hists
        for m_hist in model_histograms :
            
            temp_match = get_dist_by_name(m_hist, q_hist,dist_type)
            if (temp_match < top_match) :
                top_match = temp_match
                top_match_row = current_row
            D[current_row, current_col] = temp_match
            current_row += 1
            
        print("[ Finished computing distances for input #{}, best scoring model was #{} ]".format(current_col, top_match_row))
        best_match.append(top_match_row)
        current_col += 1
        
    return best_match, D

# %% [markdown]
# ################# Do not write below this line just run #################

# %%
# model_images - list of file names of model images
# query_images - list of file names of query images

query_images, model_images = read_files()

dist_type = 'intersect'
hist_type = 'rgb'
num_bins = 10


[best_match, D] = find_best_match(
    model_images, query_images, dist_type, hist_type, num_bins)

print("Indexes of correct retrieved images is:\n ", *np.where(best_match == np.arange(len(query_images))))
print("The Recognition rate is", sum(best_match == np.arange(len(query_images)))/len(query_images))
# Out:
# [ Finding best match among :
# 	(ROWS) - 89 model Images
# 	(COLS) - 89 query Images ]
# [ Started computing model histograms ]
# [ Finished computing model histograms ]
# [ Started computing query histograms ]
# [ Computing distances for query #0 ]
# [ Finished computing distances for input #0, best scoring model was #0 ]
# [ Computing distances for query #1 ]
# [ Finished computing distances for input #1, best scoring model was #1 ]
# [ Computing distances for query #2 ]
# [ Finished computing distances for input #2, best scoring model was #2 ]
# [ Computing distances for query #3 ]
# [ Finished computing distances for input #3, best scoring model was #3 ]
# [ Computing distances for query #4 ]
# [ Finished computing distances for input #4, best scoring model was #4 ]
# [ Computing distances for query #5 ]
# [ Finished computing distances for input #5, best scoring model was #5 ]
# [ Computing distances for query #6 ]
# [ Finished computing distances for input #6, best scoring model was #6 ]
# [ Computing distances for query #7 ]
# [ Finished computing distances for input #7, best scoring model was #32 ]
# [ Computing distances for query #8 ]
# [ Finished computing distances for input #8, best scoring model was #8 ]
# [ Computing distances for query #9 ]
# [ Finished computing distances for input #9, best scoring model was #9 ]
# [ Computing distances for query #10 ]
# [ Finished computing distances for input #10, best scoring model was #10 ]
# [ Computing distances for query #11 ]
# [ Finished computing distances for input #11, best scoring model was #11 ]
# [ Computing distances for query #12 ]
# [ Finished computing distances for input #12, best scoring model was #12 ]
# [ Computing distances for query #13 ]
# [ Finished computing distances for input #13, best scoring model was #13 ]
# [ Computing distances for query #14 ]
# [ Finished computing distances for input #14, best scoring model was #14 ]
# [ Computing distances for query #15 ]
# [ Finished computing distances for input #15, best scoring model was #65 ]
# [ Computing distances for query #16 ]
# [ Finished computing distances for input #16, best scoring model was #16 ]
# [ Computing distances for query #17 ]
# [ Finished computing distances for input #17, best scoring model was #17 ]
# [ Computing distances for query #18 ]
# [ Finished computing distances for input #18, best scoring model was #18 ]
# [ Computing distances for query #19 ]
# [ Finished computing distances for input #19, best scoring model was #19 ]
# [ Computing distances for query #20 ]
# [ Finished computing distances for input #20, best scoring model was #32 ]
# [ Computing distances for query #21 ]
# [ Finished computing distances for input #21, best scoring model was #21 ]
# [ Computing distances for query #22 ]
# [ Finished computing distances for input #22, best scoring model was #22 ]
# [ Computing distances for query #23 ]
# [ Finished computing distances for input #23, best scoring model was #23 ]
# [ Computing distances for query #24 ]
# [ Finished computing distances for input #24, best scoring model was #24 ]
# [ Computing distances for query #25 ]
# [ Finished computing distances for input #25, best scoring model was #6 ]
# [ Computing distances for query #26 ]
# [ Finished computing distances for input #26, best scoring model was #26 ]
# [ Computing distances for query #27 ]
# [ Finished computing distances for input #27, best scoring model was #27 ]
# [ Computing distances for query #28 ]
# [ Finished computing distances for input #28, best scoring model was #28 ]
# [ Computing distances for query #29 ]
# [ Finished computing distances for input #29, best scoring model was #29 ]
# [ Computing distances for query #30 ]
# [ Finished computing distances for input #30, best scoring model was #30 ]
# [ Computing distances for query #31 ]
# [ Finished computing distances for input #31, best scoring model was #65 ]
# [ Computing distances for query #32 ]
# [ Finished computing distances for input #32, best scoring model was #32 ]
# [ Computing distances for query #33 ]
# [ Finished computing distances for input #33, best scoring model was #33 ]
# [ Computing distances for query #34 ]
# [ Finished computing distances for input #34, best scoring model was #73 ]
# [ Computing distances for query #35 ]
# [ Finished computing distances for input #35, best scoring model was #48 ]
# [ Computing distances for query #36 ]
# [ Finished computing distances for input #36, best scoring model was #36 ]
# [ Computing distances for query #37 ]
# [ Finished computing distances for input #37, best scoring model was #37 ]
# [ Computing distances for query #38 ]
# [ Finished computing distances for input #38, best scoring model was #38 ]
# [ Computing distances for query #39 ]
# [ Finished computing distances for input #39, best scoring model was #39 ]
# [ Computing distances for query #40 ]
# [ Finished computing distances for input #40, best scoring model was #40 ]
# [ Computing distances for query #41 ]
# [ Finished computing distances for input #41, best scoring model was #58 ]
# [ Computing distances for query #42 ]
# [ Finished computing distances for input #42, best scoring model was #42 ]
# [ Computing distances for query #43 ]
# [ Finished computing distances for input #43, best scoring model was #43 ]
# [ Computing distances for query #44 ]
# [ Finished computing distances for input #44, best scoring model was #44 ]
# [ Computing distances for query #45 ]
# [ Finished computing distances for input #45, best scoring model was #45 ]
# [ Computing distances for query #46 ]
# [ Finished computing distances for input #46, best scoring model was #46 ]
# [ Computing distances for query #47 ]
# [ Finished computing distances for input #47, best scoring model was #3 ]
# [ Computing distances for query #48 ]
# [ Finished computing distances for input #48, best scoring model was #48 ]
# [ Computing distances for query #49 ]
# [ Finished computing distances for input #49, best scoring model was #49 ]
# [ Computing distances for query #50 ]
# [ Finished computing distances for input #50, best scoring model was #50 ]
# [ Computing distances for query #51 ]
# [ Finished computing distances for input #51, best scoring model was #51 ]
# [ Computing distances for query #52 ]
# [ Finished computing distances for input #52, best scoring model was #52 ]
# [ Computing distances for query #53 ]
# [ Finished computing distances for input #53, best scoring model was #10 ]
# [ Computing distances for query #54 ]
# [ Finished computing distances for input #54, best scoring model was #54 ]
# [ Computing distances for query #55 ]
# [ Finished computing distances for input #55, best scoring model was #55 ]
# [ Computing distances for query #56 ]
# [ Finished computing distances for input #56, best scoring model was #56 ]
# [ Computing distances for query #57 ]
# [ Finished computing distances for input #57, best scoring model was #57 ]
# [ Computing distances for query #58 ]
# [ Finished computing distances for input #58, best scoring model was #58 ]
# [ Computing distances for query #59 ]
# [ Finished computing distances for input #59, best scoring model was #59 ]
# [ Computing distances for query #60 ]
# [ Finished computing distances for input #60, best scoring model was #60 ]
# [ Computing distances for query #61 ]
# [ Finished computing distances for input #61, best scoring model was #73 ]
# [ Computing distances for query #62 ]
# [ Finished computing distances for input #62, best scoring model was #1 ]
# [ Computing distances for query #63 ]
# [ Finished computing distances for input #63, best scoring model was #1 ]
# [ Computing distances for query #64 ]
# [ Finished computing distances for input #64, best scoring model was #64 ]
# [ Computing distances for query #65 ]
# [ Finished computing distances for input #65, best scoring model was #31 ]
# [ Computing distances for query #66 ]
# [ Finished computing distances for input #66, best scoring model was #66 ]
# [ Computing distances for query #67 ]
# [ Finished computing distances for input #67, best scoring model was #69 ]
# [ Computing distances for query #68 ]
# [ Finished computing distances for input #68, best scoring model was #87 ]
# [ Computing distances for query #69 ]
# [ Finished computing distances for input #69, best scoring model was #69 ]
# [ Computing distances for query #70 ]
# [ Finished computing distances for input #70, best scoring model was #70 ]
# [ Computing distances for query #71 ]
# [ Finished computing distances for input #71, best scoring model was #71 ]
# [ Computing distances for query #72 ]
# [ Finished computing distances for input #72, best scoring model was #72 ]
# [ Computing distances for query #73 ]
# [ Finished computing distances for input #73, best scoring model was #31 ]
# [ Computing distances for query #74 ]
# [ Finished computing distances for input #74, best scoring model was #74 ]
# [ Computing distances for query #75 ]
# [ Finished computing distances for input #75, best scoring model was #75 ]
# [ Computing distances for query #76 ]
# [ Finished computing distances for input #76, best scoring model was #37 ]
# [ Computing distances for query #77 ]
# [ Finished computing distances for input #77, best scoring model was #77 ]
# [ Computing distances for query #78 ]
# [ Finished computing distances for input #78, best scoring model was #59 ]
# [ Computing distances for query #79 ]
# [ Finished computing distances for input #79, best scoring model was #79 ]
# [ Computing distances for query #80 ]
# [ Finished computing distances for input #80, best scoring model was #80 ]
# [ Computing distances for query #81 ]
# [ Finished computing distances for input #81, best scoring model was #81 ]
# [ Computing distances for query #82 ]
# [ Finished computing distances for input #82, best scoring model was #82 ]
# [ Computing distances for query #83 ]
# [ Finished computing distances for input #83, best scoring model was #83 ]
# [ Computing distances for query #84 ]
# [ Finished computing distances for input #84, best scoring model was #84 ]
# [ Computing distances for query #85 ]
# [ Finished computing distances for input #85, best scoring model was #85 ]
# [ Computing distances for query #86 ]
# [ Finished computing distances for input #86, best scoring model was #86 ]
# [ Computing distances for query #87 ]
# [ Finished computing distances for input #87, best scoring model was #87 ]
# [ Computing distances for query #88 ]
# [ Finished computing distances for input #88, best scoring model was #88 ]
# Indexes of correct retrieved images is:
#   [ 0  1  2  3  4  5  6  8  9 10 11 12 13 14 16 17 18 19 21 22 23 24 26 27
#  28 29 30 32 33 36 37 38 39 40 42 43 44 45 46 48 49 50 51 52 54 55 56 57
#  58 59 60 64 66 69 70 71 72 74 75 77 79 80 81 82 83 84 85 86 87 88]
# The Recognition rate is 0.7865168539325843

# %% [markdown]
# #### Exercise 3.b **(3 Points)**
# Implement a function **show_neighbors** which takes a list of model images and a list of
# query images and for each query image visualizes several model images which are closest to the query image
# according to the specified distance metric. Use the function find best match in your implementation. See the Figure below for example of the output.
#
# ![](https://drive.google.com/uc?export=view&id=1qlPbNzh92u9EU4kzNMbHg0uRgSk4AnRO)

# %%
def show_neighbors(model_images, query_images, dist_type, hist_type, num_bins):
    '''
    For each image file from 'query_images' find and visualize the 5 nearest images from 'model_image'.

    Note: use the previously implemented function 'find_best_match'
    Note: use subplot command to show all the images in the same Python figure, one row per query image

    '''
    k = 5
    _,D = find_best_match(model_images, query_images, dist_type, hist_type, num_bins)
    for i in range(len(query_images)):
        for j in range(len(model_images)):
            my_dist = D[:,i]
            my_dist = np.array(my_dist)
            idx = np.argpartition(my_dist, k)
            out_images = np.array(model_images)[idx]
        print(query_images[i])
        for l in range(k):
            print(out_images[l])
                

    return

# %% [markdown]
# ################# Do not write below this line just run #################

# %%
## visualize nearest neighbors
query_images_vis = [query_images[i] for i in np.array([0,4,9])]
show_neighbors(model_images, query_images_vis, dist_type, hist_type, num_bins)
# Out:
# [ Finding best match among :
# 	(ROWS) - 89 model Images
# 	(COLS) - 3 query Images ]
# [ Started computing model histograms ]
# [ Finished computing model histograms ]
# [ Started computing query histograms ]
# [ Computing distances for query #0 ]
# [ Finished computing distances for input #0, best scoring model was #0 ]
# [ Computing distances for query #1 ]
# [ Finished computing distances for input #1, best scoring model was #4 ]
# [ Computing distances for query #2 ]
# [ Finished computing distances for input #2, best scoring model was #9 ]
# query/obj100__40.png
# model/obj100__0.png
# model/obj19__0.png
# model/obj69__0.png
# model/obj33__0.png
# model/obj23__0.png
# query/obj12__40.png
# model/obj12__0.png
# model/obj51__0.png
# model/obj53__0.png
# model/obj80__0.png
# model/obj41__0.png
# query/obj17__40.png
# model/obj91__0.png
# model/obj15__0.png
# model/obj17__0.png
# model/obj3__0.png
# model/obj84__0.png

# %% [markdown]
# #### Metric
#  Use the function find best match to compute recognition rate for different combinations of distance and
# histogram functions. The recognition rate is given by a ratio between number of correct matches and total
# number of query images.

# %% [markdown]
# ################# Do not write below this line just run #################

# %%
num_correct = sum(best_match == range(len(query_images)))
print('number of correct matches: %d (%f)\n'% (num_correct, 1.0 * num_correct / len(query_images)))

# %% [markdown]
# ### Report **(4 Points)**
#
# Experiment with different functions and numbers of histogram bins, try to find
# combination that works best. **Submit the summary of your experiments in a report as part of your solution.**

# %% [markdown]
# **Write your Report here**
#
#
# |  | Number of Bins | Metric(Distance Metric) | Accuracy |
# |---|---|---|---|
# | 1 |  |  |  |
# | 2 |  |  |  |
# | 3 |  |  |  |
# | ... |  |  |  |

# %% [markdown]
# ## Question 4: [K-Means]((https://towardsdatascience.com/understanding-k-means-clustering-in-machine-learning-6a6e67336aa1))
# ###(Bonus question for **5 Points**, not compulsory)
#
# Recolor the original images and Query images by using Kmeans. And find the best matches between the two.
#
# There are several way to preprocess an image, and in this exrcise you will work with "recoloration". Given an image, you will use a Kmeans model to transform it, and use the same model to transform the images that belongs to the model folder, then repeat the previous to exercises to extract the RGB hist and find the best match. We'll provide the method to fit a KMeans model on an image and to transform an image given a KMeans model. You should then use these functions, applying them on the query images (to retrieve recolored images and a KMeans_model for each query image) and on the model images. Pay attention on the fact that you should use a model fitted on a query image on the whole model folder to have coherent results.
#
# In the following example, the KMeans model has been fitted on three different images: [Row 1] then these models are used to transform original images to recolored images [Row 2:4]
#
# ![](https://drive.google.com/uc?export=view&id=1m0Wu2n12BflIwMHL1g3LUxHurotxrPWr)

# %% [markdown]
# #### Exercise 4 - Code **(3 Points)**

# %%
from sklearn.cluster import KMeans
import numpy as np

def fitting_kmeans(query, K):
  '''
  fit a Kmeans model on 1 image.
  return the recolored image and the KM model
  '''
  shape_ = query.shape

  kmeans = KMeans(K)
  data = query.reshape(-1, 3)
  kmeans.fit(data)
  query_recolored = kmeans.cluster_centers_[kmeans.predict(data)]

  return query_recolored.reshape(shape_), kmeans


def apply_kmeans(km_model, model_image):
  '''
  transform with a Kmeans model 1 image.
  return the recolored image.
  '''

  shape_ = model_image.shape
  data = model_image.reshape(-1, 3)
  img_recolored = km_model.cluster_centers_[km_model.predict(data)]

  return img_recolored.reshape(shape_)

# %%
def compute_KM_histograms(image_list, num_bins=10):
  '''
  Function to compute histograms of a list of images.
  Leverage the "rgb_hist" function previously coded.
  '''

  #####################################################
  ##                 YOUR CODE HERE                  ##
  #####################################################

  return image_hists

# %%
def compute_KMeans(model_list, query_list, K):
  '''
  Function to compute the recolored images from both query and 
  model lists. You should:
    1. Apply the fitting metod to queries retrieving the ist of recolored
       queries and KMeans models.
    2. Apply the transforming method on all the images in the model folder
       for each KMeans you fitted in the previous step.
    3. Return the 2 lists of recolored images.
  '''
  query_recolored_imgs = []
  query_km_models = []
  model_recolored_imgs = []

  #####################################################
  ##                 YOUR CODE HERE                  ##
  #####################################################

  return query_recolored_imgs, model_recolored_imgs


def compute_recolored_hists(query_recolored, model_recolored):
  '''
  Function to compute the histograms of lists of images.
  Use the compute_KM_histograms function.
  '''
  
  #####################################################
  ##                 YOUR CODE HERE                  ##
  #####################################################

  return query_hists, model_hists


def compute_matching(q_hists, m_hists, dist_type):
  '''
  Function to compute the scores among several histograms.
  Similarly to find_best_match function you have previously defined,
  this function will return the best_match list.

  EXTRA: add the 'all' dist_type wich compute the scores for all 3 
  kind of distances, exploiting the strength of modulation!
  '''

  #####################################################
  ##                 YOUR CODE HERE                  ##
  #####################################################

  return best_match

def print_corrects_KM(match, tot_q_images, dist_type, K):
  '''
  Function to print the results.
  Input:
    match: the best_match results
    tot_images: len(model_images)
    dist_type: among 'l2', 'intersect' and 'chi2' (EXTRA: 'all')
    K: K-Means parameter
  
  last three args should be expicitly printed by this function.
  
  Example of Output:

  Settings: K=30, dist=chi2
  Results: Number of correct matches: 58/89 (65.17%)
  '''

  #####################################################
  ##                 YOUR CODE HERE                  ##
  #####################################################

def KM_matching(model_imgs, query_imgs, dist_type, K):
  '''
  Use all the functions you have just defined to print the results.
  '''

  #####################################################
  ##                 YOUR CODE HERE                  ##
  #####################################################

  return

# %% [markdown]
# ################# Do not write below this line just run #################

# %%
query_images, model_images = read_files()

K = 30
dist_type = 'all'

KM_matching(model_images, query_images, dist_type, K)

# %% [markdown]
# #### Report **(2 Points)**
#
# Experiment with different functions and numbers of clusters, try to find
# combination that works best. **Submit the summary of your experiments in a report as part of your solution.**

# %% [markdown]
# **Write your Report here**
#
#
# |  | Number of Clusters | Metric(Distance Metric) | Accuracy |
# |---|---|---|---|
# | 1 |  |  |  |
# | 2 |  |  |  |
# | 3 |  |  |  |
# | ... |  |  |  |
